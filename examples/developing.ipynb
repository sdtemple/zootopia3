# %%
import numpy
import matplotlib.pyplot as plt
from zootopia3 import *

# %%
shp = Shape("TRIANGLE", 224, 224, 100, 100, 0.5, (255, 0, 0), "triangle")
plt.imshow(shp.get_image())

# %%
shp = Shape("CIRCLE", 224, 224, 50, (255, 255, 0), "yellow")
plt.imshow(shp.get_image())

# %%
shp = Shape("diaMONd", 224, 224, 100, 100, (255, 0, 255), "purple")
plt.imshow(shp.get_image())

# %%
shp = Shape("rectangle", 224, 224, 50, 50, (0, 0, 255), "blue")
plt.imshow(shp.get_image())

# %%
y = create_sinusoid(amplitude=5, frequency=1, phase=0, vertical_shift=0,length=100)
plt.plot(y)
plt.title("Sine Wave")
plt.ylim(-10,10)
# Out:
# (-10.0, 10.0)
